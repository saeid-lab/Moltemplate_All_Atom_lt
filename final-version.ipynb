# %%
with open("2-mers-HA.gjf") as file:
    data = file.readlines()

# %%
my_list=[]
for i in data[5:99]:
    print(i.split())
    my_list.append(i.split())
    
print('------------')
print('total number of atoms:',len(my_list))
# Out:
# ['C', '-0.46305800', '2.19310500', '-1.23310200']
# ['C', '-2.46505300', '3.31285200', '-0.48103300']
# ['C', '-3.09478300', '1.98563000', '0.00075900']
# ['C', '-2.41216900', '0.72735600', '-0.58868200']
# ['C', '-0.87231700', '0.82319800', '-0.61960400']
# ['H', '-0.72501600', '2.31364600', '-2.30680800']
# ['H', '-3.13885300', '1.89964600', '1.11146100']
# ['H', '-2.84940400', '0.47997700', '-1.59084500']
# ['H', '-0.49979500', '0.76003900', '0.45261400']
# ['H', '-2.76652100', '3.53047700', '-1.53361200']
# ['C', '-4.18768100', '-1.77528800', '-1.03045100']
# ['C', '-3.77546000', '-1.13602300', '0.31653900']
# ['C', '-6.07829800', '-0.82068600', '1.04735600']
# ['C', '-6.63426000', '-1.65686100', '-0.12517700']
# ['C', '-5.56983200', '-2.46321500', '-0.90476100']
# ['H', '-3.58382600', '-1.89761600', '1.11782300']
# ['N', '-0.20166300', '-0.25774300', '-1.36253900']
# ['H', '0.73197200', '-0.50098100', '-0.98389500']
# ['C', '-0.62788600', '-0.79664300', '-2.56938400']
# ['C', '0.31675900', '-1.77220000', '-3.20113400']
# ['H', '0.22482100', '-2.77430800', '-2.76086700']
# ['H', '0.10081400', '-1.87482900', '-4.27714300']
# ['H', '1.37708700', '-1.47131700', '-3.11246100']
# ['C', '-2.80247900', '4.48896700', '0.44425300']
# ['H', '-2.28092200', '4.41367800', '1.41435300']
# ['H', '-3.90121700', '4.56192400', '0.59839600']
# ['O', '-1.71665200', '-0.50288600', '-3.06266800']
# ['O', '-2.46888000', '5.73214700', '-0.17545200']
# ['H', '-1.52880600', '5.72294900', '-0.46180900']
# ['O', '-4.42949600', '2.10426200', '-0.49793800']
# ['H', '-4.89651800', '1.21534000', '-0.46736400']
# ['O', '-1.01371700', '3.23941500', '-0.41946400']
# ['O', '-2.61177800', '-0.36562200', '0.35058600']
# ['O', '-4.82114200', '-0.21992300', '0.78519000']
# ['H', '-7.44126000', '-2.34143900', '0.24625000']
# ['H', '-3.41307400', '-2.52073600', '-1.33021200']
# ['O', '-4.38652800', '-0.81907800', '-2.06528800']
# ['H', '-3.54395400', '-0.71625400', '-2.61754300']
# ['O', '-5.31685000', '-3.65948900', '-0.15228800']
# ['H', '-5.85838800', '-4.40411400', '-0.48446400']
# ['H', '-5.94117400', '-2.71162900', '-1.92813200']
# ['C', '-5.97830600', '-1.68514900', '2.31123800']
# ['O', '-5.02398800', '-2.07407000', '2.93021300']
# ['O', '-7.25570400', '-1.99485800', '2.72370700']
# ['H', '-7.27247500', '-2.54499000', '3.55283800']
# ['H', '-6.72582500', '0.07448800', '1.26445900']
# ['C', '4.61859000', '-3.48035700', '0.25538200']
# ['C', '3.89945200', '-2.39681600', '-1.77213100']
# ['C', '3.91302000', '-1.00069700', '-1.10735600']
# ['C', '3.82521600', '-1.08967700', '0.43390400']
# ['C', '4.79638200', '-2.14073000', '1.02505300']
# ['H', '3.65111900', '-3.99572100', '0.42680000']
# ['H', '4.78437500', '-0.37599100', '-1.40793400']
# ['H', '2.76320400', '-1.25572700', '0.74816600']
# ['H', '5.84638000', '-1.75155400', '0.86854400']
# ['H', '2.88858500', '-2.86116100', '-1.68854400']
# ['C', '2.16921600', '1.26007100', '1.65461000']
# ['C', '3.60133600', '1.30798700', '1.06679800']
# ['C', '3.04655800', '3.02903400', '-0.57709400']
# ['C', '1.57082500', '3.09714800', '-0.13195300']
# ['C', '1.31130700', '2.48561100', '1.26022800']
# ['H', '4.27435500', '1.99359200', '1.65159200']
# ['N', '4.61527900', '-2.37400200', '2.47321600']
# ['H', '5.48350700', '-2.47233100', '2.99843700']
# ['C', '3.38671200', '-2.42487900', '3.13084700']
# ['C', '3.46311100', '-2.70764400', '4.60107000']
# ['H', '3.99451000', '-1.92307800', '5.15773600']
# ['H', '2.44490200', '-2.76674100', '5.02665000']
# ['H', '3.95103100', '-3.66719400', '4.82508700']
# ['C', '4.36021300', '-2.35666700', '-3.23759000']
# ['H', '5.46237700', '-2.39925900', '-3.31671500']
# ['H', '3.96558100', '-1.45778000', '-3.75581500']
# ['O', '2.32960500', '-2.25411200', '2.53355600']
# ['O', '3.77025400', '-3.43965900', '-3.95725000']
# ['H', '4.16148900', '-4.29240600', '-3.66037100']
# ['O', '2.71169200', '-0.41607100', '-1.62430700']
# ['H', '2.63466500', '0.54792300', '-1.32361100']
# ['O', '4.87148900', '-3.25972500', '-1.13526000']
# ['O', '4.34690000', '0.12543300', '1.03679800']
# ['O', '3.62584000', '1.75502900', '-0.32792800']
# ['H', '1.18849200', '4.14831700', '-0.16319600']
# ['H', '2.25491200', '1.22084500', '2.77056700']
# ['O', '1.38915500', '0.15459000', '1.19932900']
# ['H', '1.50919900', '-0.64450800', '1.80311300']
# ['O', '1.66274900', '3.48230500', '2.23185500']
# ['H', '0.90365100', '4.08050500', '2.40513600']
# ['H', '0.22701800', '2.21217000', '1.35287100']
# ['C', '3.87747300', '4.13197100', '0.08293000']
# ['O', '4.75935100', '4.06173200', '0.89876000']
# ['O', '3.47651800', '5.34247900', '-0.42576800']
# ['H', '3.98509900', '6.11124000', '-0.04420300']
# ['H', '3.12041800', '3.10750500', '-1.69917900']
# ['O', '0.94711500', '2.36937800', '-1.21094700']
# ['O', '-7.26219353', '-0.75270030', '-1.03791623']
# ------------
# total number of atoms: 94

# %%
count = 1
new_elements = []

for obj1 in my_list:
    print('$atom:{}{}\t $mol:{}\t @atom:{}\t 0.0\t {}\t {}\t {}'\
          .format(obj1[0],count,'...','Atype',obj1[1],obj1[2],obj1[3]))
    new_elements.append('{}{}'.format(obj1[0],count))
    count += 1
    
print('------------')
print(new_elements,'and total number of atoms are:',len(new_elements))
print('------------')

elements = []
for obj1 in my_list:
    elements.append(obj1[0])

print(elements)
# Out:
# $atom:C1	 $mol:...	 @atom:Atype	 0.0	 -0.46305800	 2.19310500	 -1.23310200
# $atom:C2	 $mol:...	 @atom:Atype	 0.0	 -2.46505300	 3.31285200	 -0.48103300
# $atom:C3	 $mol:...	 @atom:Atype	 0.0	 -3.09478300	 1.98563000	 0.00075900
# $atom:C4	 $mol:...	 @atom:Atype	 0.0	 -2.41216900	 0.72735600	 -0.58868200
# $atom:C5	 $mol:...	 @atom:Atype	 0.0	 -0.87231700	 0.82319800	 -0.61960400
# $atom:H6	 $mol:...	 @atom:Atype	 0.0	 -0.72501600	 2.31364600	 -2.30680800
# $atom:H7	 $mol:...	 @atom:Atype	 0.0	 -3.13885300	 1.89964600	 1.11146100
# $atom:H8	 $mol:...	 @atom:Atype	 0.0	 -2.84940400	 0.47997700	 -1.59084500
# $atom:H9	 $mol:...	 @atom:Atype	 0.0	 -0.49979500	 0.76003900	 0.45261400
# $atom:H10	 $mol:...	 @atom:Atype	 0.0	 -2.76652100	 3.53047700	 -1.53361200
# $atom:C11	 $mol:...	 @atom:Atype	 0.0	 -4.18768100	 -1.77528800	 -1.03045100
# $atom:C12	 $mol:...	 @atom:Atype	 0.0	 -3.77546000	 -1.13602300	 0.31653900
# $atom:C13	 $mol:...	 @atom:Atype	 0.0	 -6.07829800	 -0.82068600	 1.04735600
# $atom:C14	 $mol:...	 @atom:Atype	 0.0	 -6.63426000	 -1.65686100	 -0.12517700
# $atom:C15	 $mol:...	 @atom:Atype	 0.0	 -5.56983200	 -2.46321500	 -0.90476100
# $atom:H16	 $mol:...	 @atom:Atype	 0.0	 -3.58382600	 -1.89761600	 1.11782300
# $atom:N17	 $mol:...	 @atom:Atype	 0.0	 -0.20166300	 -0.25774300	 -1.36253900
# $atom:H18	 $mol:...	 @atom:Atype	 0.0	 0.73197200	 -0.50098100	 -0.98389500
# $atom:C19	 $mol:...	 @atom:Atype	 0.0	 -0.62788600	 -0.79664300	 -2.56938400
# $atom:C20	 $mol:...	 @atom:Atype	 0.0	 0.31675900	 -1.77220000	 -3.20113400
# $atom:H21	 $mol:...	 @atom:Atype	 0.0	 0.22482100	 -2.77430800	 -2.76086700
# $atom:H22	 $mol:...	 @atom:Atype	 0.0	 0.10081400	 -1.87482900	 -4.27714300
# $atom:H23	 $mol:...	 @atom:Atype	 0.0	 1.37708700	 -1.47131700	 -3.11246100
# $atom:C24	 $mol:...	 @atom:Atype	 0.0	 -2.80247900	 4.48896700	 0.44425300
# $atom:H25	 $mol:...	 @atom:Atype	 0.0	 -2.28092200	 4.41367800	 1.41435300
# $atom:H26	 $mol:...	 @atom:Atype	 0.0	 -3.90121700	 4.56192400	 0.59839600
# $atom:O27	 $mol:...	 @atom:Atype	 0.0	 -1.71665200	 -0.50288600	 -3.06266800
# $atom:O28	 $mol:...	 @atom:Atype	 0.0	 -2.46888000	 5.73214700	 -0.17545200
# $atom:H29	 $mol:...	 @atom:Atype	 0.0	 -1.52880600	 5.72294900	 -0.46180900
# $atom:O30	 $mol:...	 @atom:Atype	 0.0	 -4.42949600	 2.10426200	 -0.49793800
# $atom:H31	 $mol:...	 @atom:Atype	 0.0	 -4.89651800	 1.21534000	 -0.46736400
# $atom:O32	 $mol:...	 @atom:Atype	 0.0	 -1.01371700	 3.23941500	 -0.41946400
# $atom:O33	 $mol:...	 @atom:Atype	 0.0	 -2.61177800	 -0.36562200	 0.35058600
# $atom:O34	 $mol:...	 @atom:Atype	 0.0	 -4.82114200	 -0.21992300	 0.78519000
# $atom:H35	 $mol:...	 @atom:Atype	 0.0	 -7.44126000	 -2.34143900	 0.24625000
# $atom:H36	 $mol:...	 @atom:Atype	 0.0	 -3.41307400	 -2.52073600	 -1.33021200
# $atom:O37	 $mol:...	 @atom:Atype	 0.0	 -4.38652800	 -0.81907800	 -2.06528800
# $atom:H38	 $mol:...	 @atom:Atype	 0.0	 -3.54395400	 -0.71625400	 -2.61754300
# $atom:O39	 $mol:...	 @atom:Atype	 0.0	 -5.31685000	 -3.65948900	 -0.15228800
# $atom:H40	 $mol:...	 @atom:Atype	 0.0	 -5.85838800	 -4.40411400	 -0.48446400
# $atom:H41	 $mol:...	 @atom:Atype	 0.0	 -5.94117400	 -2.71162900	 -1.92813200
# $atom:C42	 $mol:...	 @atom:Atype	 0.0	 -5.97830600	 -1.68514900	 2.31123800
# $atom:O43	 $mol:...	 @atom:Atype	 0.0	 -5.02398800	 -2.07407000	 2.93021300
# $atom:O44	 $mol:...	 @atom:Atype	 0.0	 -7.25570400	 -1.99485800	 2.72370700
# $atom:H45	 $mol:...	 @atom:Atype	 0.0	 -7.27247500	 -2.54499000	 3.55283800
# $atom:H46	 $mol:...	 @atom:Atype	 0.0	 -6.72582500	 0.07448800	 1.26445900
# $atom:C47	 $mol:...	 @atom:Atype	 0.0	 4.61859000	 -3.48035700	 0.25538200
# $atom:C48	 $mol:...	 @atom:Atype	 0.0	 3.89945200	 -2.39681600	 -1.77213100
# $atom:C49	 $mol:...	 @atom:Atype	 0.0	 3.91302000	 -1.00069700	 -1.10735600
# $atom:C50	 $mol:...	 @atom:Atype	 0.0	 3.82521600	 -1.08967700	 0.43390400
# $atom:C51	 $mol:...	 @atom:Atype	 0.0	 4.79638200	 -2.14073000	 1.02505300
# $atom:H52	 $mol:...	 @atom:Atype	 0.0	 3.65111900	 -3.99572100	 0.42680000
# $atom:H53	 $mol:...	 @atom:Atype	 0.0	 4.78437500	 -0.37599100	 -1.40793400
# $atom:H54	 $mol:...	 @atom:Atype	 0.0	 2.76320400	 -1.25572700	 0.74816600
# $atom:H55	 $mol:...	 @atom:Atype	 0.0	 5.84638000	 -1.75155400	 0.86854400
# $atom:H56	 $mol:...	 @atom:Atype	 0.0	 2.88858500	 -2.86116100	 -1.68854400
# $atom:C57	 $mol:...	 @atom:Atype	 0.0	 2.16921600	 1.26007100	 1.65461000
# $atom:C58	 $mol:...	 @atom:Atype	 0.0	 3.60133600	 1.30798700	 1.06679800
# $atom:C59	 $mol:...	 @atom:Atype	 0.0	 3.04655800	 3.02903400	 -0.57709400
# $atom:C60	 $mol:...	 @atom:Atype	 0.0	 1.57082500	 3.09714800	 -0.13195300
# $atom:C61	 $mol:...	 @atom:Atype	 0.0	 1.31130700	 2.48561100	 1.26022800
# $atom:H62	 $mol:...	 @atom:Atype	 0.0	 4.27435500	 1.99359200	 1.65159200
# $atom:N63	 $mol:...	 @atom:Atype	 0.0	 4.61527900	 -2.37400200	 2.47321600
# $atom:H64	 $mol:...	 @atom:Atype	 0.0	 5.48350700	 -2.47233100	 2.99843700
# $atom:C65	 $mol:...	 @atom:Atype	 0.0	 3.38671200	 -2.42487900	 3.13084700
# $atom:C66	 $mol:...	 @atom:Atype	 0.0	 3.46311100	 -2.70764400	 4.60107000
# $atom:H67	 $mol:...	 @atom:Atype	 0.0	 3.99451000	 -1.92307800	 5.15773600
# $atom:H68	 $mol:...	 @atom:Atype	 0.0	 2.44490200	 -2.76674100	 5.02665000
# $atom:H69	 $mol:...	 @atom:Atype	 0.0	 3.95103100	 -3.66719400	 4.82508700
# $atom:C70	 $mol:...	 @atom:Atype	 0.0	 4.36021300	 -2.35666700	 -3.23759000
# $atom:H71	 $mol:...	 @atom:Atype	 0.0	 5.46237700	 -2.39925900	 -3.31671500
# $atom:H72	 $mol:...	 @atom:Atype	 0.0	 3.96558100	 -1.45778000	 -3.75581500
# $atom:O73	 $mol:...	 @atom:Atype	 0.0	 2.32960500	 -2.25411200	 2.53355600
# $atom:O74	 $mol:...	 @atom:Atype	 0.0	 3.77025400	 -3.43965900	 -3.95725000
# $atom:H75	 $mol:...	 @atom:Atype	 0.0	 4.16148900	 -4.29240600	 -3.66037100
# $atom:O76	 $mol:...	 @atom:Atype	 0.0	 2.71169200	 -0.41607100	 -1.62430700
# $atom:H77	 $mol:...	 @atom:Atype	 0.0	 2.63466500	 0.54792300	 -1.32361100
# $atom:O78	 $mol:...	 @atom:Atype	 0.0	 4.87148900	 -3.25972500	 -1.13526000
# $atom:O79	 $mol:...	 @atom:Atype	 0.0	 4.34690000	 0.12543300	 1.03679800
# $atom:O80	 $mol:...	 @atom:Atype	 0.0	 3.62584000	 1.75502900	 -0.32792800
# $atom:H81	 $mol:...	 @atom:Atype	 0.0	 1.18849200	 4.14831700	 -0.16319600
# $atom:H82	 $mol:...	 @atom:Atype	 0.0	 2.25491200	 1.22084500	 2.77056700
# $atom:O83	 $mol:...	 @atom:Atype	 0.0	 1.38915500	 0.15459000	 1.19932900
# $atom:H84	 $mol:...	 @atom:Atype	 0.0	 1.50919900	 -0.64450800	 1.80311300
# $atom:O85	 $mol:...	 @atom:Atype	 0.0	 1.66274900	 3.48230500	 2.23185500
# $atom:H86	 $mol:...	 @atom:Atype	 0.0	 0.90365100	 4.08050500	 2.40513600
# $atom:H87	 $mol:...	 @atom:Atype	 0.0	 0.22701800	 2.21217000	 1.35287100
# $atom:C88	 $mol:...	 @atom:Atype	 0.0	 3.87747300	 4.13197100	 0.08293000
# $atom:O89	 $mol:...	 @atom:Atype	 0.0	 4.75935100	 4.06173200	 0.89876000
# $atom:O90	 $mol:...	 @atom:Atype	 0.0	 3.47651800	 5.34247900	 -0.42576800
# $atom:H91	 $mol:...	 @atom:Atype	 0.0	 3.98509900	 6.11124000	 -0.04420300
# $atom:H92	 $mol:...	 @atom:Atype	 0.0	 3.12041800	 3.10750500	 -1.69917900
# $atom:O93	 $mol:...	 @atom:Atype	 0.0	 0.94711500	 2.36937800	 -1.21094700
# $atom:O94	 $mol:...	 @atom:Atype	 0.0	 -7.26219353	 -0.75270030	 -1.03791623
# ------------
# ['C1', 'C2', 'C3', 'C4', 'C5', 'H6', 'H7', 'H8', 'H9', 'H10', 'C11', 'C12', 'C13', 'C14', 'C15', 'H16', 'N17', 'H18', 'C19', 'C20', 'H21', 'H22', 'H23', 'C24', 'H25', 'H26', 'O27', 'O28', 'H29', 'O30', 'H31', 'O32', 'O33', 'O34', 'H35', 'H36', 'O37', 'H38', 'O39', 'H40', 'H41', 'C42', 'O43', 'O44', 'H45', 'H46', 'C47', 'C48', 'C49', 'C50', 'C51', 'H52', 'H53', 'H54', 'H55', 'H56', 'C57', 'C58', 'C59', 'C60', 'C61', 'H62', 'N63', 'H64', 'C65', 'C66', 'H67', 'H68', 'H69', 'C70', 'H71', 'H72', 'O73', 'O74', 'H75', 'O76', 'H77', 'O78', 'O79', 'O80', 'H81', 'H82', 'O83', 'H84', 'O85', 'H86', 'H87', 'C88', 'O89', 'O90', 'H91', 'H92', 'O93', 'O94'] and total number of atoms are: 94
# ------------
# ['C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'C', 'C', 'H', 'N', 'H', 'C', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'O', 'O', 'H', 'O', 'H', 'O', 'O', 'O', 'H', 'H', 'O', 'H', 'O', 'H', 'H', 'C', 'O', 'O', 'H', 'H', 'C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'C', 'C', 'C', 'C', 'C', 'H', 'N', 'H', 'C', 'C', 'H', 'H', 'H', 'C', 'H', 'H', 'O', 'O', 'H', 'O', 'H', 'O', 'O', 'O', 'H', 'H', 'O', 'H', 'O', 'H', 'H', 'C', 'O', 'O', 'H', 'H', 'O', 'O']

# %%
all_connectivity=[]
conn_data = data[100:195]
for i in conn_data:
    print(i.split())
    all_connectivity.append(i.split())
    
print('------------')

connectivity=[]
for i in range(len(all_connectivity)):
    if len(all_connectivity[i]) >2:
        print(all_connectivity[i])
        connectivity.append(all_connectivity[i])
        
print('------------')
print('this is connectivity:\n',connectivity)
# Out:
# ['1', '5', '1.0', '6', '1.0', '32', '1.0', '93', '1.0']
# ['2', '3', '1.0', '10', '1.0', '24', '1.0', '32', '1.0']
# ['3', '4', '1.0', '7', '1.0', '30', '1.0']
# ['4', '5', '1.0', '8', '1.0', '33', '1.0']
# ['5', '17', '1.0']
# ['6']
# ['7']
# ['8']
# ['9']
# ['10']
# ['11', '12', '1.0', '15', '1.0', '36', '1.0', '37', '1.0']
# ['12', '16', '1.0', '33', '1.0', '34', '1.0']
# ['13', '14', '1.0', '34', '1.0', '42', '1.0', '46', '1.0']
# ['14', '15', '1.0', '35', '1.0', '94', '1.0']
# ['15', '39', '1.0', '41', '1.0']
# ['16']
# ['17', '18', '1.0', '19', '1.0']
# ['18']
# ['19', '20', '1.0', '27', '2.0']
# ['20', '21', '1.0', '22', '1.0', '23', '1.0']
# ['21']
# ['22']
# ['23']
# ['24', '25', '1.0', '26', '1.0', '28', '1.0']
# ['25']
# ['26']
# ['27']
# ['28', '29', '1.0']
# ['29']
# ['30', '31', '1.0']
# ['31']
# ['32']
# ['33']
# ['34']
# ['35']
# ['36']
# ['37', '38', '1.0']
# ['38']
# ['39', '40', '1.0']
# ['40']
# ['41']
# ['42', '43', '2.0', '44', '1.0']
# ['43']
# ['44', '45', '1.0']
# ['45']
# ['46']
# ['47', '51', '1.0', '52', '1.0', '78', '1.0']
# ['48', '49', '1.0', '56', '1.0', '70', '1.0', '78', '1.0']
# ['49', '50', '1.0', '53', '1.0', '76', '1.0']
# ['50', '51', '1.0', '54', '1.0', '79', '1.0']
# ['51', '55', '1.0', '63', '1.0']
# ['52']
# ['53']
# ['54']
# ['55']
# ['56']
# ['57', '58', '1.0', '61', '1.0', '82', '1.0', '83', '1.0']
# ['58', '62', '1.0', '79', '1.0', '80', '1.0']
# ['59', '60', '1.0', '80', '1.0', '88', '1.0', '92', '1.0']
# ['60', '61', '1.0', '81', '1.0', '93', '1.0']
# ['61', '85', '1.0', '87', '1.0']
# ['62']
# ['63', '64', '1.0', '65', '1.0']
# ['64']
# ['65', '66', '1.0', '73', '2.0']
# ['66', '67', '1.0', '68', '1.0', '69', '1.0']
# ['67']
# ['68']
# ['69']
# ['70', '71', '1.0', '72', '1.0', '74', '1.0']
# ['71']
# ['72']
# ['73']
# ['74', '75', '1.0']
# ['75']
# ['76', '77', '1.0']
# ['77']
# ['78']
# ['79']
# ['80']
# ['81']
# ['82']
# ['83', '84', '1.0']
# ['84']
# ['85', '86', '1.0']
# ['86']
# ['87']
# ['88', '89', '2.0', '90', '1.0']
# ['89']
# ['90', '91', '1.0']
# ['91']
# ['92']
# ['93']
# ['94']
# []
# ------------
# ['1', '5', '1.0', '6', '1.0', '32', '1.0', '93', '1.0']
# ['2', '3', '1.0', '10', '1.0', '24', '1.0', '32', '1.0']
# ['3', '4', '1.0', '7', '1.0', '30', '1.0']
# ['4', '5', '1.0', '8', '1.0', '33', '1.0']
# ['5', '17', '1.0']
# ['11', '12', '1.0', '15', '1.0', '36', '1.0', '37', '1.0']
# ['12', '16', '1.0', '33', '1.0', '34', '1.0']
# ['13', '14', '1.0', '34', '1.0', '42', '1.0', '46', '1.0']
# ['14', '15', '1.0', '35', '1.0', '94', '1.0']
# ['15', '39', '1.0', '41', '1.0']
# ['17', '18', '1.0', '19', '1.0']
# ['19', '20', '1.0', '27', '2.0']
# ['20', '21', '1.0', '22', '1.0', '23', '1.0']
# ['24', '25', '1.0', '26', '1.0', '28', '1.0']
# ['28', '29', '1.0']
# ['30', '31', '1.0']
# ['37', '38', '1.0']
# ['39', '40', '1.0']
# ['42', '43', '2.0', '44', '1.0']
# ['44', '45', '1.0']
# ['47', '51', '1.0', '52', '1.0', '78', '1.0']
# ['48', '49', '1.0', '56', '1.0', '70', '1.0', '78', '1.0']
# ['49', '50', '1.0', '53', '1.0', '76', '1.0']
# ['50', '51', '1.0', '54', '1.0', '79', '1.0']
# ['51', '55', '1.0', '63', '1.0']
# ['57', '58', '1.0', '61', '1.0', '82', '1.0', '83', '1.0']
# ['58', '62', '1.0', '79', '1.0', '80', '1.0']
# ['59', '60', '1.0', '80', '1.0', '88', '1.0', '92', '1.0']
# ['60', '61', '1.0', '81', '1.0', '93', '1.0']
# ['61', '85', '1.0', '87', '1.0']
# ['63', '64', '1.0', '65', '1.0']
# ['65', '66', '1.0', '73', '2.0']
# ['66', '67', '1.0', '68', '1.0', '69', '1.0']
# ['70', '71', '1.0', '72', '1.0', '74', '1.0']
# ['74', '75', '1.0']
# ['76', '77', '1.0']
# ['83', '84', '1.0']
# ['85', '86', '1.0']
# ['88', '89', '2.0', '90', '1.0']
# ['90', '91', '1.0']
# ------------
# this is connectivity:
#  [['1', '5', '1.0', '6', '1.0', '32', '1.0', '93', '1.0'], ['2', '3', '1.0', '10', '1.0', '24', '1.0', '32', '1.0'], ['3', '4', '1.0', '7', '1.0', '30', '1.0'], ['4', '5', '1.0', '8', '1.0', '33', '1.0'], ['5', '17', '1.0'], ['11', '12', '1.0', '15', '1.0', '36', '1.0', '37', '1.0'], ['12', '16', '1.0', '33', '1.0', '34', '1.0'], ['13', '14', '1.0', '34', '1.0', '42', '1.0', '46', '1.0'], ['14', '15', '1.0', '35', '1.0', '94', '1.0'], ['15', '39', '1.0', '41', '1.0'], ['17', '18', '1.0', '19', '1.0'], ['19', '20', '1.0', '27', '2.0'], ['20', '21', '1.0', '22', '1.0', '23', '1.0'], ['24', '25', '1.0', '26', '1.0', '28', '1.0'], ['28', '29', '1.0'], ['30', '31', '1.0'], ['37', '38', '1.0'], ['39', '40', '1.0'], ['42', '43', '2.0', '44', '1.0'], ['44', '45', '1.0'], ['47', '51', '1.0', '52', '1.0', '78', '1.0'], ['48', '49', '1.0', '56', '1.0', '70', '1.0', '78', '1.0'], ['49', '50', '1.0', '53', '1.0', '76', '1.0'], ['50', '51', '1.0', '54', '1.0', '79', '1.0'], ['51', '55', '1.0', '63', '1.0'], ['57', '58', '1.0', '61', '1.0', '82', '1.0', '83', '1.0'], ['58', '62', '1.0', '79', '1.0', '80', '1.0'], ['59', '60', '1.0', '80', '1.0', '88', '1.0', '92', '1.0'], ['60', '61', '1.0', '81', '1.0', '93', '1.0'], ['61', '85', '1.0', '87', '1.0'], ['63', '64', '1.0', '65', '1.0'], ['65', '66', '1.0', '73', '2.0'], ['66', '67', '1.0', '68', '1.0', '69', '1.0'], ['70', '71', '1.0', '72', '1.0', '74', '1.0'], ['74', '75', '1.0'], ['76', '77', '1.0'], ['83', '84', '1.0'], ['85', '86', '1.0'], ['88', '89', '2.0', '90', '1.0'], ['90', '91', '1.0']]

# %%
for i in range(0, len(connectivity)):
    while connectivity[i].count('1.0') >0 :
        connectivity[i].remove('1.0')
        
    while connectivity[i].count('1.5') >0 :
        connectivity[i].remove('1.5')
        
    while connectivity[i].count('2.0') >0 :
        connectivity[i].remove('2.0')
        
    while connectivity[i].count('3.0') >0 :
        connectivity[i].remove('3.0')
        
    connectivity[i] = [int(float(i)) for i in connectivity[i]]
        
print(connectivity)
# Out:
# [[1, 5, 6, 32, 93], [2, 3, 10, 24, 32], [3, 4, 7, 30], [4, 5, 8, 33], [5, 17], [11, 12, 15, 36, 37], [12, 16, 33, 34], [13, 14, 34, 42, 46], [14, 15, 35, 94], [15, 39, 41], [17, 18, 19], [19, 20, 27], [20, 21, 22, 23], [24, 25, 26, 28], [28, 29], [30, 31], [37, 38], [39, 40], [42, 43, 44], [44, 45], [47, 51, 52, 78], [48, 49, 56, 70, 78], [49, 50, 53, 76], [50, 51, 54, 79], [51, 55, 63], [57, 58, 61, 82, 83], [58, 62, 79, 80], [59, 60, 80, 88, 92], [60, 61, 81, 93], [61, 85, 87], [63, 64, 65], [65, 66, 73], [66, 67, 68, 69], [70, 71, 72, 74], [74, 75], [76, 77], [83, 84], [85, 86], [88, 89, 90], [90, 91]]

# %%
my_new_list = []
for i in range(0, len(connectivity)):
    for j in connectivity[i]:
        my_new_list.append([connectivity[i][0], j])
print(my_new_list)
# Out:
# [[1, 1], [1, 5], [1, 6], [1, 32], [1, 93], [2, 2], [2, 3], [2, 10], [2, 24], [2, 32], [3, 3], [3, 4], [3, 7], [3, 30], [4, 4], [4, 5], [4, 8], [4, 33], [5, 5], [5, 17], [11, 11], [11, 12], [11, 15], [11, 36], [11, 37], [12, 12], [12, 16], [12, 33], [12, 34], [13, 13], [13, 14], [13, 34], [13, 42], [13, 46], [14, 14], [14, 15], [14, 35], [14, 94], [15, 15], [15, 39], [15, 41], [17, 17], [17, 18], [17, 19], [19, 19], [19, 20], [19, 27], [20, 20], [20, 21], [20, 22], [20, 23], [24, 24], [24, 25], [24, 26], [24, 28], [28, 28], [28, 29], [30, 30], [30, 31], [37, 37], [37, 38], [39, 39], [39, 40], [42, 42], [42, 43], [42, 44], [44, 44], [44, 45], [47, 47], [47, 51], [47, 52], [47, 78], [48, 48], [48, 49], [48, 56], [48, 70], [48, 78], [49, 49], [49, 50], [49, 53], [49, 76], [50, 50], [50, 51], [50, 54], [50, 79], [51, 51], [51, 55], [51, 63], [57, 57], [57, 58], [57, 61], [57, 82], [57, 83], [58, 58], [58, 62], [58, 79], [58, 80], [59, 59], [59, 60], [59, 80], [59, 88], [59, 92], [60, 60], [60, 61], [60, 81], [60, 93], [61, 61], [61, 85], [61, 87], [63, 63], [63, 64], [63, 65], [65, 65], [65, 66], [65, 73], [66, 66], [66, 67], [66, 68], [66, 69], [70, 70], [70, 71], [70, 72], [70, 74], [74, 74], [74, 75], [76, 76], [76, 77], [83, 83], [83, 84], [85, 85], [85, 86], [88, 88], [88, 89], [88, 90], [90, 90], [90, 91]]

# %%
bonds = []
for i,j in my_new_list:
    if i!=j:
        print(new_elements[i-1],new_elements[j-1])
        bonds.append([new_elements[i-1],new_elements[j-1]])
print('total number of bonds:', len(bonds))
# Out:
# C1 C5
# C1 H6
# C1 O32
# C1 O93
# C2 C3
# C2 H10
# C2 C24
# C2 O32
# C3 C4
# C3 H7
# C3 O30
# C4 C5
# C4 H8
# C4 O33
# C5 N17
# C11 C12
# C11 C15
# C11 H36
# C11 O37
# C12 H16
# C12 O33
# C12 O34
# C13 C14
# C13 O34
# C13 C42
# C13 H46
# C14 C15
# C14 H35
# C14 O94
# C15 O39
# C15 H41
# N17 H18
# N17 C19
# C19 C20
# C19 O27
# C20 H21
# C20 H22
# C20 H23
# C24 H25
# C24 H26
# C24 O28
# O28 H29
# O30 H31
# O37 H38
# O39 H40
# C42 O43
# C42 O44
# O44 H45
# C47 C51
# C47 H52
# C47 O78
# C48 C49
# C48 H56
# C48 C70
# C48 O78
# C49 C50
# C49 H53
# C49 O76
# C50 C51
# C50 H54
# C50 O79
# C51 H55
# C51 N63
# C57 C58
# C57 C61
# C57 H82
# C57 O83
# C58 H62
# C58 O79
# C58 O80
# C59 C60
# C59 O80
# C59 C88
# C59 H92
# C60 C61
# C60 H81
# C60 O93
# C61 O85
# C61 H87
# N63 H64
# N63 C65
# C65 C66
# C65 O73
# C66 H67
# C66 H68
# C66 H69
# C70 H71
# C70 H72
# C70 O74
# O74 H75
# O76 H77
# O83 H84
# O85 H86
# C88 O89
# C88 O90
# O90 H91
# total number of bonds: 96

# %%
count = 0
for i,j in my_new_list:
    if i!=j:
        print('$bond:bnd{} $atom:{} $atom:{}'.format(count,new_elements[i-1],new_elements[j-1]))
        
    count += 1
# Out:
# $bond:bnd1 $atom:C1 $atom:C5
# $bond:bnd2 $atom:C1 $atom:H6
# $bond:bnd3 $atom:C1 $atom:O32
# $bond:bnd4 $atom:C1 $atom:O93
# $bond:bnd6 $atom:C2 $atom:C3
# $bond:bnd7 $atom:C2 $atom:H10
# $bond:bnd8 $atom:C2 $atom:C24
# $bond:bnd9 $atom:C2 $atom:O32
# $bond:bnd11 $atom:C3 $atom:C4
# $bond:bnd12 $atom:C3 $atom:H7
# $bond:bnd13 $atom:C3 $atom:O30
# $bond:bnd15 $atom:C4 $atom:C5
# $bond:bnd16 $atom:C4 $atom:H8
# $bond:bnd17 $atom:C4 $atom:O33
# $bond:bnd19 $atom:C5 $atom:N17
# $bond:bnd21 $atom:C11 $atom:C12
# $bond:bnd22 $atom:C11 $atom:C15
# $bond:bnd23 $atom:C11 $atom:H36
# $bond:bnd24 $atom:C11 $atom:O37
# $bond:bnd26 $atom:C12 $atom:H16
# $bond:bnd27 $atom:C12 $atom:O33
# $bond:bnd28 $atom:C12 $atom:O34
# $bond:bnd30 $atom:C13 $atom:C14
# $bond:bnd31 $atom:C13 $atom:O34
# $bond:bnd32 $atom:C13 $atom:C42
# $bond:bnd33 $atom:C13 $atom:H46
# $bond:bnd35 $atom:C14 $atom:C15
# $bond:bnd36 $atom:C14 $atom:H35
# $bond:bnd37 $atom:C14 $atom:O94
# $bond:bnd39 $atom:C15 $atom:O39
# $bond:bnd40 $atom:C15 $atom:H41
# $bond:bnd42 $atom:N17 $atom:H18
# $bond:bnd43 $atom:N17 $atom:C19
# $bond:bnd45 $atom:C19 $atom:C20
# $bond:bnd46 $atom:C19 $atom:O27
# $bond:bnd48 $atom:C20 $atom:H21
# $bond:bnd49 $atom:C20 $atom:H22
# $bond:bnd50 $atom:C20 $atom:H23
# $bond:bnd52 $atom:C24 $atom:H25
# $bond:bnd53 $atom:C24 $atom:H26
# $bond:bnd54 $atom:C24 $atom:O28
# $bond:bnd56 $atom:O28 $atom:H29
# $bond:bnd58 $atom:O30 $atom:H31
# $bond:bnd60 $atom:O37 $atom:H38
# $bond:bnd62 $atom:O39 $atom:H40
# $bond:bnd64 $atom:C42 $atom:O43
# $bond:bnd65 $atom:C42 $atom:O44
# $bond:bnd67 $atom:O44 $atom:H45
# $bond:bnd69 $atom:C47 $atom:C51
# $bond:bnd70 $atom:C47 $atom:H52
# $bond:bnd71 $atom:C47 $atom:O78
# $bond:bnd73 $atom:C48 $atom:C49
# $bond:bnd74 $atom:C48 $atom:H56
# $bond:bnd75 $atom:C48 $atom:C70
# $bond:bnd76 $atom:C48 $atom:O78
# $bond:bnd78 $atom:C49 $atom:C50
# $bond:bnd79 $atom:C49 $atom:H53
# $bond:bnd80 $atom:C49 $atom:O76
# $bond:bnd82 $atom:C50 $atom:C51
# $bond:bnd83 $atom:C50 $atom:H54
# $bond:bnd84 $atom:C50 $atom:O79
# $bond:bnd86 $atom:C51 $atom:H55
# $bond:bnd87 $atom:C51 $atom:N63
# $bond:bnd89 $atom:C57 $atom:C58
# $bond:bnd90 $atom:C57 $atom:C61
# $bond:bnd91 $atom:C57 $atom:H82
# $bond:bnd92 $atom:C57 $atom:O83
# $bond:bnd94 $atom:C58 $atom:H62
# $bond:bnd95 $atom:C58 $atom:O79
# $bond:bnd96 $atom:C58 $atom:O80
# $bond:bnd98 $atom:C59 $atom:C60
# $bond:bnd99 $atom:C59 $atom:O80
# $bond:bnd100 $atom:C59 $atom:C88
# $bond:bnd101 $atom:C59 $atom:H92
# $bond:bnd103 $atom:C60 $atom:C61
# $bond:bnd104 $atom:C60 $atom:H81
# $bond:bnd105 $atom:C60 $atom:O93
# $bond:bnd107 $atom:C61 $atom:O85
# $bond:bnd108 $atom:C61 $atom:H87
# $bond:bnd110 $atom:N63 $atom:H64
# $bond:bnd111 $atom:N63 $atom:C65
# $bond:bnd113 $atom:C65 $atom:C66
# $bond:bnd114 $atom:C65 $atom:O73
# $bond:bnd116 $atom:C66 $atom:H67
# $bond:bnd117 $atom:C66 $atom:H68
# $bond:bnd118 $atom:C66 $atom:H69
# $bond:bnd120 $atom:C70 $atom:H71
# $bond:bnd121 $atom:C70 $atom:H72
# $bond:bnd122 $atom:C70 $atom:O74
# $bond:bnd124 $atom:O74 $atom:H75
# $bond:bnd126 $atom:O76 $atom:H77
# $bond:bnd128 $atom:O83 $atom:H84
# $bond:bnd130 $atom:O85 $atom:H86
# $bond:bnd132 $atom:C88 $atom:O89
# $bond:bnd133 $atom:C88 $atom:O90
# $bond:bnd135 $atom:O90 $atom:H91
